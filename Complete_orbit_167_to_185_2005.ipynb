# %%
# checkmark

# %%
from Functions import *

# %%
windowsize = 7
estimatedNumCrossings = 11
year = 2005
start_day = 172
end_day = 174.8
day_data1 = get_day_data(start_day, end_day, year)
plot_KSM(day_data1, year, start_day, end_day, xFormat = "Hour")
entries1, exits1, ax1, ksmcoords_2_1,cross_array1= identify_crossings_2(day_data1, windowsize, estimatedNumCrossings,3,2,200)
# Out:
# Sample start date:  2005-06-21 00:00:30
# Sample end date: 2005-06-23 19:12:30
# Start Date:  2005-06-21 00:00:30
# End Date:  2005-06-23 19:11:30

# %%
print(cross_array1)
if '2005-06-22 12:00:30' not in cross_array1:
    cross_array1.insert(3,'2005-06-22 12:00:30')
print(cross_array1)
# Out:
# ['2005-06-21 14:31:30', '2005-06-21 17:55:30', '2005-06-22 09:00:30', '2005-06-23 05:30:30', '2005-06-23 06:34:30', '2005-06-23 12:24:30', '2005-06-23 14:13:30', '2005-06-23 17:27:30']
# ['2005-06-21 14:31:30', '2005-06-21 17:55:30', '2005-06-22 09:00:30', '2005-06-22 12:00:30', '2005-06-23 05:30:30', '2005-06-23 06:34:30', '2005-06-23 12:24:30', '2005-06-23 14:13:30', '2005-06-23 17:27:30']

# %%
windowsize = 7
estimatedNumCrossings = 8
year = 2005
start_day = 182.55
end_day = 185
day_data2 = get_day_data(start_day, end_day, year)
plot_KSM(day_data2, year, start_day, end_day, xFormat = "Hour")
entries2, exits2, ax2, ksmcoords_2_2,cross_array2= identify_crossings_2(day_data2, windowsize, estimatedNumCrossings,3,2,200)
# Out:
# Sample start date:  2005-07-01 13:12:30
# Sample end date: 2005-07-04 00:00:30
# Start Date:  2005-07-01 13:12:30
# End Date:  2005-07-03 23:59:30

# %%
print(cross_array2)
# Out:
# ['2005-07-01 15:21:30', '2005-07-01 18:49:30', '2005-07-01 20:42:30', '2005-07-02 05:13:30', '2005-07-02 09:43:30', '2005-07-02 17:21:30', '2005-07-02 20:21:30', '2005-07-03 14:41:30', '2005-07-03 17:34:30', '2005-07-03 18:23:30', '2005-07-03 22:03:30']

# %%
cross_array_total = cross_array1+cross_array2
print(cross_array_total, len(cross_array_total))
# Out:
# ['2005-06-21 14:31:30', '2005-06-21 17:55:30', '2005-06-22 09:00:30', '2005-06-22 12:00:30', '2005-06-23 05:30:30', '2005-06-23 06:34:30', '2005-06-23 12:24:30', '2005-06-23 14:13:30', '2005-06-23 17:27:30', '2005-07-01 15:21:30', '2005-07-01 18:49:30', '2005-07-01 20:42:30', '2005-07-02 05:13:30', '2005-07-02 09:43:30', '2005-07-02 17:21:30', '2005-07-02 20:21:30', '2005-07-03 14:41:30', '2005-07-03 17:34:30', '2005-07-03 18:23:30', '2005-07-03 22:03:30'] 20

# %%
day_data = get_day_data(172,185, 2005)
# Out:
# Sample start date:  2005-06-21 00:00:30
# Sample end date: 2005-07-04 00:00:30

# %%
BU1 = selectBvector('2005-06-21 00:00:30', cross_array_total[0], time_width = 40, data = day_data , exclude_time = 5)
BD1 = selectBvector(cross_array_total[0],cross_array_total[1], time_width = 40, data = day_data , exclude_time = 5)

BD2 = selectBvector(cross_array_total[0], cross_array_total[1], time_width = 40, data = day_data , exclude_time = 5)
BU2= selectBvector(cross_array_total[1], cross_array_total[2], time_width = 40, data = day_data , exclude_time = 5)

BU3 = selectBvector(cross_array_total[1], cross_array_total[2], time_width = 40, data = day_data , exclude_time = 5)
BD3 = selectBvector(cross_array_total[2], cross_array_total[3], time_width = 40, data = day_data , exclude_time = 5)

BD4 = selectBvector(cross_array_total[2], cross_array_total[3], time_width = 40, data = day_data , exclude_time = 5)
BU4 = selectBvector(cross_array_total[3], cross_array_total[4], time_width = 40, data = day_data , exclude_time = 5)

BU5 = selectBvector(cross_array_total[3], cross_array_total[4], time_width = 40, data = day_data , exclude_time = 5)
BD5 = selectBvector(cross_array_total[4], cross_array_total[5], time_width = 40, data = day_data , exclude_time = 5)

BD6 = selectBvector(cross_array_total[4], cross_array_total[5], time_width = 40, data = day_data , exclude_time = 5)
BU6 = selectBvector(cross_array_total[5], cross_array_total[6], time_width = 40, data = day_data , exclude_time = 5)

BU7 = selectBvector(cross_array_total[5], cross_array_total[6], time_width = 40, data = day_data , exclude_time = 5)
BD7 = selectBvector(cross_array_total[6], cross_array_total[7], time_width = 40, data = day_data , exclude_time = 5)

BD8 = selectBvector(cross_array_total[6], cross_array_total[7], time_width = 40, data = day_data , exclude_time = 5)
BU8 = selectBvector(cross_array_total[7], cross_array_total[8], time_width = 40, data = day_data , exclude_time = 5)

BU9 = selectBvector(cross_array_total[7], cross_array_total[8], time_width = 40, data = day_data , exclude_time = 5)
BD9 = selectBvector(cross_array_total[8], '2005-06-23 19:12:30', time_width = 40, data = day_data , exclude_time = 5)

BD10 = selectBvector('2005-07-01 13:12:30', cross_array_total[9], time_width = 40, data = day_data , exclude_time = 5)
BU10 = selectBvector(cross_array_total[9], cross_array_total[10], time_width = 40, data = day_data , exclude_time = 5)

BU11 = selectBvector(cross_array_total[9], cross_array_total[10], time_width = 20, data = day_data , exclude_time = 2)
BD11 = selectBvector(cross_array_total[10], cross_array_total[11], time_width = 20, data = day_data , exclude_time = 2)

BD12 = selectBvector(cross_array_total[10], cross_array_total[11], time_width = 20, data = day_data , exclude_time = 5)
BU12 = selectBvector(cross_array_total[11], cross_array_total[12], time_width = 20, data = day_data , exclude_time = 5)

BU13 = selectBvector(cross_array_total[11], cross_array_total[12], time_width = 20, data = day_data , exclude_time = 2)
BD13 = selectBvector(cross_array_total[12], cross_array_total[13], time_width = 20, data = day_data , exclude_time = 2)

BD14 = selectBvector(cross_array_total[12], cross_array_total[13], time_width = 20, data = day_data , exclude_time = 2)
BU14 = selectBvector(cross_array_total[13], cross_array_total[14], time_width = 20, data = day_data , exclude_time = 2)

BU15 = selectBvector(cross_array_total[13], cross_array_total[14], time_width = 20, data = day_data , exclude_time = 2)
BD15 = selectBvector(cross_array_total[14], cross_array_total[15], time_width = 20, data = day_data , exclude_time = 2)

BD16 = selectBvector(cross_array_total[14], cross_array_total[15], time_width = 20, data = day_data , exclude_time = 2)
BU16 = selectBvector(cross_array_total[15], cross_array_total[16], time_width = 20, data = day_data , exclude_time = 2)

BU17 = selectBvector(cross_array_total[15], cross_array_total[16], time_width = 20, data = day_data , exclude_time = 2)
BD17 = selectBvector(cross_array_total[16], cross_array_total[17], time_width = 20, data = day_data , exclude_time = 2)

BD18 = selectBvector(cross_array_total[16], cross_array_total[17], time_width = 20, data = day_data , exclude_time = 2)
BU18 = selectBvector(cross_array_total[17], cross_array_total[18], time_width = 20, data = day_data , exclude_time = 2)

BU19 = selectBvector(cross_array_total[17], cross_array_total[18], time_width = 20, data = day_data , exclude_time = 2)
BD19 = selectBvector(cross_array_total[18], cross_array_total[19], time_width = 20, data = day_data , exclude_time = 2)
# we give up the last crossing, only focus on the 19 crossings because the last one cannot be calculated

# %%
ncps = {}
shock_vs = {}
aves = {}
stds = {}
BU_list = [BU1,BU2,BU3,BU4,BU5,BU6,BU7,BU8, BU9,BU10,BU11,BU12,BU13,BU14,BU15,BU16,BU17,BU18,BU19]
BD_list = [BD1,BD2,BD3,BD4,BD5,BD6,BD7,BD8, BD9,BD10,BD11,BD12,BD13,BD14,BD15,BD16,BD17,BD18,BD19]
for i in range(len(BU_list)):
    ncp,shock_value,ave,std = ncp_shock4(BU_list[i],BD_list[i],5,i+1)
    ncps['ncp'+str(i+1)] = ncp
    shock_vs['shock_value'+str(i+1)] = shock_value
    aves['average_shock'+str(i+1)] = ave
    stds['std'+str(i+1)] = std
# Out:
# S=1 θ_BN value = 43.84391081126204
# Standard deviation = 3.586655158401427
# S=2 θ_BN value = 8.476818272435914
# Standard deviation = 4.408190899198829
# S=3 θ_BN value = 74.15208121073134
# Standard deviation = 3.2032670980598525
# S=4 θ_BN value = 44.3701667767288
# Standard deviation = 3.251311768935563
# S=5 θ_BN value = 49.347921334563544
# Standard deviation = 5.794684255039576
# S=6 θ_BN value = 51.58512553430903
# Standard deviation = 4.45114606497894
# S=7 θ_BN value = 73.55547515972661
# Standard deviation = 7.747959720325332
# S=8 θ_BN value = 84.09559997475307
# Standard deviation = 5.502415158256415
# S=9 θ_BN value = 71.16856780637767
# Standard deviation = 3.169730371044323
# S=10 θ_BN value = 80.60799536819648
# Standard deviation = 2.7160943382568483
# S=11 θ_BN value = 74.19530640814133
# Standard deviation = 2.7981203700240087
# S=12 θ_BN value = 80.70769517867684
# Standard deviation = 1.6832653101395234
# S=13 θ_BN value = 86.55857515075297
# ...

# %%
shock_vs_list = []
for i in shock_vs.values():
    shock_vs_list.append(i)
Plot_Dist_for_theta(shock_vs_list)
plt.title("Kurtosis vs Skewness for Days 172 to 185, 2005")
# Out:
# Text(0.5, 1.0, 'Kurtosis vs Skewness for Days 172 to 185, 2005')

# %%
ncp_list = []
ave_ncp = []
std_ncp = []
for value in ncps.values():
    ncp_list.append(value)
print(len(ncp_list[0]))
for i in range(18):
    ncp_S = ncp_list[i]
    ave_value = np.sum(ncp_S, axis =0)/len(ncp_S)
    ave_ncp.append(ave_value)
    std = np.sqrt(np.sum((ncp_S - ave_value)**2, axis = 0)/len(ncp_S))
    std_ncp.append(std)
print(ave_value)
cross_array_total.pop()

# %%
x_ncp,rho_ncp,srho_ncp=plotncp(day_data,cross_array_total,1,ave_ncp,std_ncp,-1,8)
plt.ylim(0,50)
plt.xlim(18,26)
plt.gca().invert_yaxis()

# %%
t,st=calCPM(day_data,cross_array_total,ave_ncp,rho_ncp,std_ncp,srho_ncp)

plt.ylim(30,36)
plt.xlim(19,22)
