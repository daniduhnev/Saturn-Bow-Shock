# %%
from Functions import *

# %%
windowsize = 7
estimatedNumCrossings = 9.5
year=2005
start_day1 =101
end_day1 = 103.1

day_data1_2004 = get_day_data(start_day1, end_day1, year)
#plot_KSM(day_data1_2004, year, start_day1, end_day1, xFormat = "Hour")
entries1, exits1, ax1, ksmcoords_1,cross_array1 = identify_crossings_2(day_data1_2004, windowsize, estimatedNumCrossings,3,2,100)
plt.title("Crossings Identified (Days {}-{}, {})".format(start_day1, end_day1,year),fontsize = 14)

print(cross_array1)
# Out:
# Sample start date:  2005-04-11 00:00:30
# Sample end date: 2005-04-13 02:24:30
# ['2005-04-12 00:17:30', '2005-04-12 02:40:30', '2005-04-12 10:40:30', '2005-04-12 15:30:30', '2005-04-12 21:16:30', '2005-04-12 22:08:30', '2005-04-13 00:29:30', '2005-04-13 01:08:30']

# %%
estimatedNumCrossings = 10

start_day2 = 110.75
end_day2 = 115
day_data2_2004 = get_day_data(start_day2, end_day2, year)
#plot_KSM(day_data2_2004, year, start_day2, end_day2, xFormat = "Hour")
entries2, exits2, ax2, ksmcoords_2,cross_array2 = identify_crossings_2(day_data2_2004, windowsize, estimatedNumCrossings,3,2,230)
plt.title("Crossings Identified (Days {}-{}, {})".format(start_day2, end_day2,year),fontsize = 14)

print(cross_array2)
# Out:
# Sample start date:  2005-04-20 18:00:30
# Sample end date: 2005-04-25 00:00:30
# ['2005-04-20 18:38:30', '2005-04-20 19:00:30', '2005-04-21 01:26:30', '2005-04-21 08:47:30', '2005-04-21 10:46:30', '2005-04-24 04:18:30', '2005-04-24 05:44:30', '2005-04-24 08:30:30', '2005-04-24 12:49:30', '2005-04-24 21:52:30']

# %%
cross_array = cross_array1 + cross_array2
print('crossing dates',cross_array)
day_data_2004 = get_day_data(start_day1,end_day2,year)
day_data_2004.index.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# crossing dates ['2005-04-12 00:17:30', '2005-04-12 02:40:30', '2005-04-12 10:40:30', '2005-04-12 15:30:30', '2005-04-12 21:16:30', '2005-04-12 22:08:30', '2005-04-13 00:29:30', '2005-04-13 01:08:30', '2005-04-20 18:38:30', '2005-04-20 19:00:30', '2005-04-21 01:26:30', '2005-04-21 08:47:30', '2005-04-21 10:46:30', '2005-04-24 04:18:30', '2005-04-24 05:44:30', '2005-04-24 08:30:30', '2005-04-24 12:49:30', '2005-04-24 21:52:30']
# Sample start date:  2005-04-11 00:00:30
# Sample end date: 2005-04-25 00:00:30
# Index(['2005-04-11 00:00:30', '2005-04-11 00:01:30', '2005-04-11 00:02:30',
#        '2005-04-11 00:03:30', '2005-04-11 00:04:30', '2005-04-11 00:05:30',
#        '2005-04-11 00:06:30', '2005-04-11 00:07:30', '2005-04-11 00:08:30',
#        '2005-04-11 00:09:30',
#        ...
#        '2005-04-24 23:50:30', '2005-04-24 23:51:30', '2005-04-24 23:52:30',
#        '2005-04-24 23:53:30', '2005-04-24 23:54:30', '2005-04-24 23:55:30',
#        '2005-04-24 23:56:30', '2005-04-24 23:57:30', '2005-04-24 23:58:30',
#        '2005-04-24 23:59:30'],
#       dtype='object', name='Time', length=19983)

# %%
offset=4
mins=8+offset

b1, b2 = extract_B_vector3(cross_array, day_data_2004, mins,offset)

type1 = ['exit','entry', 'exit', 'entry', 'exit' ,'entry', 'exit','entry', 'exit', 'entry', 'exit' ,'entry', 'exit','entry', 'exit','entry', 'exit','entry']
num = np.arange(1, len(cross_array)+1, 1)

ncp,ave_ncp,std_ncp,shock_v,ave_shock, std = ncp_shock3(b1, b2, 8, num, type1)
# Out:
# S=1 θ_BN value = 43.09028345117728
# Standard deviation = 14.488368074117666
# S=2 θ_BN value = 39.80206255645756
# Standard deviation = 15.983203432141035
# S=3 θ_BN value = 69.06540371628478
# Standard deviation = 9.11776760075971
# S=4 θ_BN value = 63.86051774026707
# Standard deviation = 6.6649281616401135
# S=5 θ_BN value = 60.850237712683196
# Standard deviation = 8.348593636556988
# S=6 θ_BN value = 60.60799645949726
# Standard deviation = 7.288428098412805
# S=7 θ_BN value = 56.78960899999153
# Standard deviation = 15.911825373634255
# S=8 θ_BN value = 78.07390788098652
# Standard deviation = 5.934517582246973
# S=9 θ_BN value = 24.868999914930278
# Standard deviation = 18.303544790612953
# S=10 θ_BN value = 51.766438119984414
# Standard deviation = 15.413558784172793
# S=11 θ_BN value = 57.19788867891967
# Standard deviation = 10.307413432658592
# S=12 θ_BN value = 77.86508555605747
# Standard deviation = 3.6308716241618253
# S=13 θ_BN value = 59.994761468672415
# Standard deviation = 7.617654414879213
# S=14 θ_BN value = 52.55626015504758
# Standard deviation = 14.433043563869557
# S=15 θ_BN value = 61.408170584525294
# Standard deviation = 12.205048107521092
# S=16 θ_BN value = 24.01701191850699
# Standard deviation = 14.811099618183793
# S=17 θ_BN value = 48.19809563234995
# Standard deviation = 21.40612054956567
# S=18 θ_BN value = 30.64344121064985
# Standard deviation = 20.861418084800746

# %%
plt.figure(figsize = (12,10))
Plot_Dist_for_theta([*shock_v])
plt.title("Kurtosis vs Skewness (Days 101-116, 2005)", fontsize = 15)
plt.xlabel("Kurtosis of ${\Theta}_{BN}$", fontsize = 15)
plt.ylabel("Skewness of ${\Theta}_{BN}$", fontsize = 15)
# Out:
# Text(0, 0.5, 'Skewness of ${\\Theta}_{BN}$')

# %%
def plotncp(day_data,cross_array,scal,ave_ncp,std_ncp,point1,point2):
    plt.figure(figsize=(10,12))
    a=[]
    b=[]
    c=[]

    #x.invert_yaxis()
    #ax.plot(day_data['X'],day_data['Rs'],color='k',label='orbit path')
    for i in range(len(cross_array)):
        X=day_data.loc[cross_array[i],'X']
        RHO=day_data.loc[cross_array[i],'Rs']
        Y=day_data.loc[cross_array[i],'Y']
        Z=day_data.loc[cross_array[i],'Z']
        plt.plot(X,RHO,'o',color='k')
        S='S'+str(i+1)
        plt.annotate(S, (X-1.7,RHO ))
        x_ncp=ave_ncp[i][0]
        y_ncp=ave_ncp[i][1]
        z_ncp=ave_ncp[i][2]
        sx_ncp=std_ncp[i][0]
        sy_ncp=std_ncp[i][1]
        sz_ncp=std_ncp[i][2]
        
        dot=[Y,Z]/RHO
        rho_ncp=np.dot([y_ncp,z_ncp],dot)
        srho_ncp=np.dot([sy_ncp,sz_ncp],dot)
        errorr=srho_ncp*scal
        errorx=sx_ncp*scal
        plt.plot(X,RHO,'o',color='k')
        if (x_ncp*scal)>=0:
            plt.plot([X,X+(x_ncp*scal)],[RHO,RHO+(rho_ncp*scal)],color='k')
            plt.errorbar(X+(x_ncp*scal),RHO+(rho_ncp*scal),xerr=errorx,yerr=errorr,color='k')
        else:
            plt.plot([X,X+(x_ncp*-scal)],[RHO,RHO+(rho_ncp*-scal)],color='k')
            plt.errorbar(X+(x_ncp*-scal),RHO+(rho_ncp*-scal),xerr=errorx,yerr=errorr,color='k')
        
        a.append(x_ncp)
        b.append(rho_ncp)
        c.append(srho_ncp)
    #ax.legend()
    
    
    plt.gca().invert_yaxis
    plotcross(day_data,cross_array,point1,point2,ave_ncp,std_ncp)
    return a,b,c

# %%
x_ncp,rho_ncp,srho_ncp=plotncp(day_data_2004,cross_array,-3,ave_ncp,std_ncp,7,17)
plt.ylim(0,50)
plt.xlim(-15,25)
plt.xlabel(r"$X_{KSM}  \left(R_s\right)$",fontsize = 12)
plt.ylabel(r"$\left(Y_{KSM}^2 + Z_{KSM}^2\right)^{1/2} \left(R_s\right)$",fontsize = 12)
plt.title("Projections of Co-planarity Normals (Days 101-116, 2005)", fontsize = 15)
plt.gca().invert_yaxis()

# %%
t,st=calCPM(day_data_2004,cross_array,ave_ncp,rho_ncp,std_ncp,srho_ncp)
plt.ylim(19,23)
plt.xlim(15,18)
plt.xlabel(r"$X_{KSM}  \left(R_s\right)$",fontsize = 12)
plt.ylabel(r"$\left(Y_{KSM}^2 + Z_{KSM}^2\right)^{1/2} \left(R_s\right)$",fontsize = 12)
plt.title('A Representation of Norm Vectors \n (Days 101-116, 2005)',fontsize = 15)
plt.gca().set_aspect('equal', adjustable='box')
plt.draw()
# Out:
# Theta_CPM  [22.374047976611067, 32.34118124688385, 3.4657661982790415, 11.880228762229493, 12.603434502158535, 19.058691764552776, 49.07003320446478, 10.621738000969003, 73.28828001598833, 82.42788666602263, 12.890285069195201, 14.489384833252657, 2.7387067111183114, 57.26608817368938, 88.35406975189518, 18.57581781369302, 31.384630862978696, 24.736620892120612]
# Std [13.307684579367683, 19.338621017568773, 9.261288127697485, 14.345943603286383, 21.043280471059678, 4.788759017896323, 19.851950621859103, 17.783616699037555, 27.362119978195246, 11.508459686348091, 12.319706130441347, 12.374492966706667, 8.544590542469752, 19.302664309687476, 21.841208998486668, 15.57958792866211, 29.082774354961728, 16.870836939606622]

# %%
plt.figure()
plt.plot(ave_shock,t,'.')
plt.xlabel('Shock Angle ${\Theta}_{BN}$',fontsize = 12)
plt.ylabel('Angle Between Model and Co-planarity Normals ${\Theta}_{CPM}$ ',fontsize = 12)
plt.title('Shock Angle ${\Theta}_{BN}$ vs ${\Theta}_{CPM}$ (Days 101-116, 2005)',fontsize = 15)
plt.errorbar(ave_shock,t,xerr=std/2,yerr=st,fmt='o',color='k')
plt.ylim(-10,100)
plt.xlim(0,90 )
for i in range(len(srho_ncp)):
    S='S'+str(i+1)
    plt.annotate(S, (ave_shock[i],t[i]+1) )
