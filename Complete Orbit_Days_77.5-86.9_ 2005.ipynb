# %%
from Functions import *

# %%
windowsize = 7
estimatedNumCrossings = 7
year = 2005
start_day = 77.5
end_day = 80
day_data1 = get_day_data(start_day, end_day, year)
plot_KSM(day_data1, year, start_day, end_day, xFormat = "Hour")
entries1, exits1, ax1, ksmcoords_2_1,cross_array1= identify_crossings_2(day_data1, windowsize, estimatedNumCrossings,3,2,200)
# Out:
# Sample start date:  2005-03-18 12:00:30
# Sample end date: 2005-03-21 00:00:30
# Start Date:  2005-03-18 12:00:30
# End Date:  2005-03-20 23:59:30

# %%
print(cross_array1)
# Out:
# ['2005-03-18 23:08:30', '2005-03-19 02:37:30', '2005-03-19 08:21:30', '2005-03-20 02:11:30', '2005-03-20 08:16:30', '2005-03-20 09:22:30', '2005-03-20 14:39:30', '2005-03-20 17:24:30']

# %%
windowsize = 7
estimatedNumCrossings = 8
year = 2005
start_day = 85
end_day = 86.9
day_data2 = get_day_data(start_day, end_day, year)
plot_KSM(day_data2, year, start_day, end_day, xFormat = "Hour")
entries2, exits2, ax2, ksmcoords_2_2,cross_array2= identify_crossings_2(day_data2, windowsize, estimatedNumCrossings,3,2,200)
# Out:
# Sample start date:  2005-03-26 00:00:30
# Sample end date: 2005-03-27 21:36:30
# Start Date:  2005-03-26 00:00:30
# End Date:  2005-03-27 21:35:30

# %%
print(cross_array2)
cross_array2.remove('2005-03-27 21:32:30')
print('removed:')
print(cross_array2)
# Out:
# ['2005-03-26 08:44:30', '2005-03-26 22:53:30', '2005-03-27 00:14:30', '2005-03-27 02:39:30', '2005-03-27 05:24:30', '2005-03-27 07:08:30', '2005-03-27 09:02:30', '2005-03-27 21:32:30']
# removed:
# ['2005-03-26 08:44:30', '2005-03-26 22:53:30', '2005-03-27 00:14:30', '2005-03-27 02:39:30', '2005-03-27 05:24:30', '2005-03-27 07:08:30', '2005-03-27 09:02:30']

# %%
cross_array_total = cross_array1+cross_array2
print(cross_array_total)
print(len(cross_array_total))
# Out:
# ['2005-03-18 23:08:30', '2005-03-19 02:37:30', '2005-03-19 08:21:30', '2005-03-20 02:11:30', '2005-03-20 08:16:30', '2005-03-20 09:22:30', '2005-03-20 14:39:30', '2005-03-20 17:24:30', '2005-03-26 08:44:30', '2005-03-26 22:53:30', '2005-03-27 00:14:30', '2005-03-27 02:39:30', '2005-03-27 05:24:30', '2005-03-27 07:08:30', '2005-03-27 09:02:30']
# 15

# %%
day_data = get_day_data(77.5,86.9, 2005)
# Out:
# Sample start date:  2005-03-18 12:00:30
# Sample end date: 2005-03-27 21:36:30

# %%
BU1 = selectBvector('2005-03-18 12:00:30', cross_array_total[0], time_width = 40, data = day_data , exclude_time = 5)
BD1 = selectBvector(cross_array_total[0],cross_array_total[1], time_width = 40, data = day_data , exclude_time = 5)

BD2 = selectBvector(cross_array_total[0], cross_array_total[1], time_width = 40, data = day_data , exclude_time = 5)
BU2= selectBvector(cross_array_total[1], cross_array_total[2], time_width = 40, data = day_data , exclude_time = 5)

BU3 = selectBvector(cross_array_total[1], cross_array_total[2], time_width = 40, data = day_data , exclude_time = 5)
BD3 = selectBvector(cross_array_total[2], cross_array_total[3], time_width = 40, data = day_data , exclude_time = 5)

BD4 = selectBvector(cross_array_total[2], cross_array_total[3], time_width = 40, data = day_data , exclude_time = 5)
BU4 = selectBvector(cross_array_total[3], cross_array_total[4], time_width = 40, data = day_data , exclude_time = 5)

BU5 = selectBvector(cross_array_total[3], cross_array_total[4], time_width = 40, data = day_data , exclude_time = 5)
BD5 = selectBvector(cross_array_total[4], cross_array_total[5], time_width = 40, data = day_data , exclude_time = 5)

BD6 = selectBvector(cross_array_total[4], cross_array_total[5], time_width = 40, data = day_data , exclude_time = 5)
BU6 = selectBvector(cross_array_total[5], cross_array_total[6], time_width = 40, data = day_data , exclude_time = 5)

BU7 = selectBvector(cross_array_total[5], cross_array_total[6], time_width = 40, data = day_data , exclude_time = 5)
BD7 = selectBvector(cross_array_total[6], cross_array_total[7], time_width = 40, data = day_data , exclude_time = 5)

BD8 = selectBvector(cross_array_total[6], cross_array_total[7], time_width = 40, data = day_data , exclude_time = 5)
BU8 = selectBvector(cross_array_total[7], cross_array_total[8], time_width = 40, data = day_data , exclude_time = 5)

BU9 = selectBvector(cross_array_total[7], cross_array_total[8], time_width = 40, data = day_data , exclude_time = 5)
BD9 = selectBvector(cross_array_total[8], cross_array_total[9], time_width = 40, data = day_data , exclude_time = 5)

BD10 = selectBvector(cross_array_total[8], cross_array_total[9], time_width = 40, data = day_data , exclude_time = 5)
BU10 = selectBvector(cross_array_total[9], cross_array_total[10], time_width = 40, data = day_data , exclude_time = 5)

BU11 = selectBvector(cross_array_total[9], cross_array_total[10], time_width = 40, data = day_data , exclude_time = 5)
BD11 = selectBvector(cross_array_total[10], cross_array_total[11], time_width = 40, data = day_data , exclude_time = 5)

BD12 = selectBvector(cross_array_total[10], cross_array_total[11], time_width = 40, data = day_data , exclude_time = 5)
BU12 = selectBvector(cross_array_total[11], cross_array_total[12], time_width = 40, data = day_data , exclude_time = 5)

BU13 = selectBvector(cross_array_total[11], cross_array_total[12], time_width = 40, data = day_data , exclude_time = 5)
BD13 = selectBvector(cross_array_total[12], cross_array_total[13], time_width = 40, data = day_data , exclude_time = 5)

BD14 = selectBvector(cross_array_total[12], cross_array_total[13], time_width = 40, data = day_data , exclude_time = 5)
BU14 = selectBvector(cross_array_total[13], cross_array_total[14], time_width = 40, data = day_data , exclude_time = 5)

BU15 = selectBvector(cross_array_total[13], cross_array_total[14], time_width = 40, data = day_data , exclude_time = 5)
BD15 = selectBvector(cross_array_total[14], '2005-03-27 21:35:30', time_width = 40, data = day_data , exclude_time = 5)

# %%
ncps = {}
shock_vs = {}
aves = {}
stds = {}
BU_list = [BU1,BU2,BU3,BU4,BU5,BU6,BU7,BU8, BU9,BU10,BU11,BU12,BU13,BU14,BU15]
BD_list = [BD1,BD2,BD3,BD4,BD5,BD6,BD7,BD8, BD9,BD10,BD11,BD12,BD13,BD14,BD15]
for i in range(len(BU_list)):
    ncp,shock_value,ave,std = ncp_shock4(BU_list[i],BD_list[i],5,i+1)
    ncps['ncp'+str(i+1)] = ncp
    shock_vs['shock_value'+str(i+1)] = shock_value
    aves['average_shock'+str(i+1)] = ave
    stds['std'+str(i+1)] = std
# Out:
# S=1 θ_BN value = 48.79105115292575
# Standard deviation = 8.024185146006875
# S=2 θ_BN value = 81.93113341489587
# Standard deviation = 5.90613679878506
# S=3 θ_BN value = 55.35126322900217
# Standard deviation = 7.274149443036964
# S=4 θ_BN value = 49.82439421523055
# Standard deviation = 4.906522484773449
# S=5 θ_BN value = 81.63043383494511
# Standard deviation = 4.2737337628541825
# S=6 θ_BN value = 76.58145459206983
# Standard deviation = 4.807477610113175
# S=7 θ_BN value = 78.9329464326346
# Standard deviation = 8.431402536898773
# S=8 θ_BN value = 39.69308820851327
# Standard deviation = 2.924121299026096
# S=9 θ_BN value = 75.41759873994963
# Standard deviation = 3.127741301907265
# S=10 θ_BN value = 22.819142052583928
# Standard deviation = 7.742241003820744
# S=11 θ_BN value = 54.068866788006204
# Standard deviation = 10.105892967855612
# S=12 θ_BN value = 23.658531542903557
# Standard deviation = 15.29107524230571
# S=13 θ_BN value = 77.3071129084049
# Standard deviation = 5.112211640951291
# S=14 θ_BN value = 52.354831718388596
# Standard deviation = 8.320014839541583
# S=15 θ_BN value = 53.441006257911084
# Standard deviation = 7.971018737119402

# %%
shock_vs_list = []
for i in shock_vs.values():
    shock_vs_list.append(i)
Plot_Dist_for_theta(shock_vs_list)
plt.title("Kurtosis vs Skewness for Days 77.5 to 86.9, 2005", fontsize = 15)
plt.xlabel("Kurtosis of ${\Theta}_{BN}$", fontsize = 15)
plt.ylabel("Skewness of ${\Theta}_{BN}$", fontsize = 15)
# Out:
# Text(0, 0.5, 'Skewness of ${\\Theta}_{BN}$')

# %%
# x_ncp,rho_ncp,srho_ncp=plotncp(day_data,cross_array_total,3,ave_ncp,std_ncp,-1,17)
# plt.ylim(0,50)
# plt.xlim(-15,25)
# plt.gca().invert_yaxis()

# %%
ncp_list = []
ave_ncp = []
std_ncp = []
for value in ncps.values():
    ncp_list.append(value)
print(len(ncp_list[0]))
for i in range(15):
    ncp_S = ncp_list[i]
    ave_value = np.sum(ncp_S, axis =0)/len(ncp_S)
    ave_ncp.append(ave_value)
    std = np.sqrt(np.sum((ncp_S - ave_value)**2, axis = 0)/len(ncp_S))
    std_ncp.append(std)
# Out:
# 25

# %%
x_ncp,rho_ncp,srho_ncp=plotncp(day_data,cross_array_total,-2,ave_ncp,std_ncp,10,7)
plt.ylim(10,46)
plt.xlim(0,40)
plt.gca().invert_yaxis()

# %%
t,st=calCPM(day_data,cross_array_total,ave_ncp,rho_ncp,std_ncp,srho_ncp)
plt.ylim(39,42)
plt.xlim(15,19)
plr.title()
# Out:
# Theta_CPM  [49.140764683539885, 72.23439689849545, 69.67246676616685, 52.242476657015516, 35.71416154157944, 54.583218258568444, 76.33225193586449, 56.96181681160924, 76.65846445575895, 14.64763972148451, 24.077923471737208, 50.544270332527105, 58.29358007541076, 22.039935972805537, 22.27185208079557]
# Std [4.174747856322142, 4.011539181509014, 1.453074464037509, 1.4416221231845088, 32.427043856604705, 15.33926175220618, 6.53611713727556, 1.8111521517785452, 2.364334559305132, 1.531615949477724, 11.683057568650497, 7.0635821930754155, 1.172507493164723, 2.1920352009170383, 2.449651912465329]
# (15.0, 19.0)
