# %%
from Functions import *

# %%
windowsize = 7
estimatedNumCrossings = 6
year = 2005
start_day = 187
end_day = 189.5
day_data1 = get_day_data(start_day, end_day, year)
plot_KSM(day_data1, year, start_day, end_day, xFormat = "Hour")
entries1, exits1, ax1, ksmcoords_2_1,cross_array1= identify_crossings_2(day_data1, windowsize, estimatedNumCrossings,3,2,200)
# Out:
# Sample start date:  2005-07-06 00:00:30
# Sample end date: 2005-07-08 12:00:30
# Start Date:  2005-07-06 00:00:30
# End Date:  2005-07-08 11:59:30

# %%
print(cross_array1)
# Out:
# ['2005-07-06 16:14:30', '2005-07-06 19:24:30', '2005-07-07 14:36:30', '2005-07-07 14:57:30', '2005-07-07 18:54:30', '2005-07-07 22:47:30']

# %%
windowsize = 7
estimatedNumCrossings = 6
year = 2005
start_day = 192
end_day = 194
day_data2 = get_day_data(start_day, end_day, year)
plot_KSM(day_data2, year, start_day, end_day, xFormat = "Hour")
entries2, exits2, ax2, ksmcoords_2_2,cross_array2= identify_crossings_2(day_data2, windowsize, estimatedNumCrossings,3,2,200)
# Out:
# Sample start date:  2005-07-11 00:00:30
# Sample end date: 2005-07-13 00:00:30
# Start Date:  2005-07-11 00:00:30
# End Date:  2005-07-12 23:59:30

# %%
cross_array2.insert(0,'2005-07-11 05:33:30')
print(cross_array2)
cross_array2.insert(3,'2005-07-11 18:34:30')
cross_array2.pop()
cross_array2.pop()
print(cross_array2)
# Out:
# ['2005-07-11 05:33:30', '2005-07-11 11:14:30', '2005-07-11 15:04:30', '2005-07-12 09:11:30', '2005-07-12 15:43:30', '2005-07-12 19:38:30', '2005-07-12 21:00:30']
# ['2005-07-11 05:33:30', '2005-07-11 11:14:30', '2005-07-11 15:04:30', '2005-07-11 18:34:30', '2005-07-12 09:11:30', '2005-07-12 15:43:30']

# %%
cross_array_total = cross_array1+cross_array2
print(len(cross_array_total))
print(cross_array_total)
# Out:
# 12
# ['2005-07-06 16:14:30', '2005-07-06 19:24:30', '2005-07-07 14:36:30', '2005-07-07 14:57:30', '2005-07-07 18:54:30', '2005-07-07 22:47:30', '2005-07-11 05:33:30', '2005-07-11 11:14:30', '2005-07-11 15:04:30', '2005-07-11 18:34:30', '2005-07-12 09:11:30', '2005-07-12 15:43:30']

# %%
day_data = get_day_data(186,195, 2005)
# Out:
# Sample start date:  2005-07-05 00:00:30
# Sample end date: 2005-07-14 00:00:30

# %%
BD1 = selectBvector('2005-07-06 00:00:30' , cross_array_total[0], time_width = 40, data = day_data , exclude_time = 2)
BU1 = selectBvector(cross_array_total[0],cross_array_total[1], time_width = 40, data = day_data , exclude_time = 2)

BU2 = selectBvector(cross_array_total[0], cross_array_total[1], time_width = 40, data = day_data , exclude_time = 2)
BD2= selectBvector(cross_array_total[1], cross_array_total[2], time_width = 40, data = day_data , exclude_time = 2)

BD3 = selectBvector(cross_array_total[1], cross_array_total[2], time_width = 40, data = day_data , exclude_time = 2)
BU3 = selectBvector(cross_array_total[2], cross_array_total[3], time_width = 10, data = day_data , exclude_time = 2)

BU4 = selectBvector(cross_array_total[2], cross_array_total[3], time_width = 10, data = day_data , exclude_time = 2)
BD4 = selectBvector(cross_array_total[3], cross_array_total[4], time_width = 40, data = day_data , exclude_time = 2)

BD5 = selectBvector(cross_array_total[3], cross_array_total[4], time_width = 40, data = day_data , exclude_time = 2)
BU5 = selectBvector(cross_array_total[4], cross_array_total[5], time_width = 40, data = day_data , exclude_time = 2)

BU6 = selectBvector(cross_array_total[4], cross_array_total[5], time_width = 40, data = day_data , exclude_time = 2)
BD6 = selectBvector(cross_array_total[5], '2005-07-08 11:59:30', time_width = 40, data = day_data , exclude_time = 2)

BD7 = selectBvector('2005-07-11 00:00:30' , cross_array_total[6], time_width = 40, data = day_data , exclude_time = 2)
BU7 = selectBvector(cross_array_total[6], cross_array_total[7], time_width = 40, data = day_data , exclude_time = 2)

BU8 = selectBvector(cross_array_total[6], cross_array_total[7], time_width = 40, data = day_data , exclude_time =2)
BD8 = selectBvector(cross_array_total[7], cross_array_total[8], time_width = 40, data = day_data , exclude_time = 2)

BD9 = selectBvector(cross_array_total[7], cross_array_total[8], time_width = 40, data = day_data , exclude_time = 2)
BU9 = selectBvector(cross_array_total[8], cross_array_total[9], time_width = 40, data = day_data , exclude_time = 2)

BU10 = selectBvector(cross_array_total[8] , cross_array_total[9], time_width = 40, data = day_data , exclude_time = 2)
BD10 = selectBvector(cross_array_total[9], cross_array_total[10], time_width = 40, data = day_data , exclude_time = 2)

BD11 = selectBvector(cross_array_total[9], cross_array_total[10], time_width = 40, data = day_data , exclude_time = 2)
BU11 = selectBvector(cross_array_total[10], cross_array_total[11], time_width = 40, data = day_data , exclude_time = 2)

BU12 = selectBvector(cross_array_total[10], cross_array_total[11], time_width = 40, data = day_data , exclude_time = 2)
BD12 = selectBvector(cross_array_total[11], '2005-07-12 23:59:30' , time_width = 40, data = day_data , exclude_time = 2)

# %%
ncps = {}
shock_vs = {}
aves = {}
stds = {}
BU_list = [BU1,BU2,BU3,BU4,BU5,BU6,BU7,BU8, BU9,BU10,BU11,BU12]
BD_list = [BD1,BD2,BD3,BD4,BD5,BD6,BD7,BD8, BD9,BD10,BD11,BD12]
for i in range(len(BU_list)):
    ncp,shock_value,ave,std = ncp_shock4(BU_list[i],BD_list[i],5,i+1)
    ncps['ncp'+str(i+1)] = ncp
    shock_vs['shock_value'+str(i+1)] = shock_value
    aves['average_shock'+str(i+1)] = ave
    stds['std'+str(i+1)] = std
# Out:
# S=1 θ_BN value = 49.583743110879524
# Standard deviation = 1.486578022510593
# S=2 θ_BN value = 51.5428304610341
# Standard deviation = 2.7396273717097923
# S=3 θ_BN value = 53.70387284039659
# Standard deviation = 5.167764150862455
# S=4 θ_BN value = 23.10114049691802
# Standard deviation = 8.377390930319502
# S=5 θ_BN value = 35.20955025741839
# Standard deviation = 6.516603274489373
# S=6 θ_BN value = 83.87645187516252
# Standard deviation = 3.6207045278321957
# S=7 θ_BN value = 80.15336939872098
# Standard deviation = 7.621783182740508
# S=8 θ_BN value = 59.17530194499834
# Standard deviation = 7.484955149165673
# S=9 θ_BN value = 63.92227152456172
# Standard deviation = 9.034613463437244
# S=10 θ_BN value = 32.39334112166163
# Standard deviation = 19.96439576927348
# S=11 θ_BN value = 76.46657224225685
# Standard deviation = 9.337661847115893
# S=12 θ_BN value = 13.860042837975175
# Standard deviation = 8.456669201929886

# %%
shock_vs_list = []
for i in shock_vs.values():
    shock_vs_list.append(i)
Plot_Dist_for_theta(shock_vs_list)
plt.title("Kurtosis vs Skewness for Days 345 to 361, 2005", fontsize = 15)
plt.xlabel("Kurtosis of ${\Theta}_{BN}$", fontsize = 15)
plt.ylabel("Skewness of ${\Theta}_{BN}$", fontsize = 15)
# Out:
# Text(0, 0.5, 'Skewness of ${\\Theta}_{BN}$')

# %%
ncp_list = []
ave_ncp = []
std_ncp = []
for value in ncps.values():
    ncp_list.append(value)
print(len(ncp_list[0]))
for i in range(12):
    ncp_S = ncp_list[i]
    ave_value = np.sum(ncp_S, axis =0)/len(ncp_S)
    ave_ncp.append(ave_value)
    std = np.sqrt(np.sum((ncp_S - ave_value)**2, axis = 0)/len(ncp_S))
    std_ncp.append(std)
print(ave_value)
# Out:
# 25
# [-0.5981665  -0.5981665  -0.52689756]

# %%
x_ncp,rho_ncp,srho_ncp=plotncp(day_data,cross_array_total,3,ave_ncp,std_ncp,1,12)
plt.ylim(10,46)
plt.xlim(15,25)
plt.gca().invert_yaxis()

# %%
t,st=calCPM(day_data,cross_array_total,ave_ncp,rho_ncp,std_ncp,srho_ncp)
plt.ylim(35,38)
plt.xlim(16,20)
# Out:
# Theta_CPM  [10.755198588716581, 32.17868950247621, 30.24343636713573, 28.307219493336433, 74.13330914631783, 80.9773191507208, 59.23832480416516, 72.45322524573805, 72.42489646077877, 18.166792409130665, 78.42209442448345, 65.55415362720788]
# Std [3.2765450153951647, 6.4313528880646125, 21.008579136263847, 9.160742108983559, 0.8773217747001911, 3.8264671574483993, 5.278098625009105, 0.7906329550214494, 6.677022785400504, 5.247819640769092, 12.101137760400363, 0.6132362790261993]
# (16.0, 20.0)

# %%
ave_shock = [value for value in aves.values()]
plt.figure()
plt.plot(ave_shock,t,'.')
plt.xlabel('shock angle ${\Theta}_{BN}$')
plt.ylabel('Angle between model and coplanarity normals ${\Theta}_{CPM}$ ')
plt.errorbar(ave_shock,t,xerr=std,yerr=st,fmt='o',color='k')
plt.ylim(-10,100)
plt.xlim(0,90 )
for i in range(len(srho_ncp)):
    S='S'+str(i+1)
    plt.annotate(S, (ave_shock[i],t[i]+1) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-dfaa526c1c8d> in <module>
#       4 plt.xlabel('shock angle ${\Theta}_{BN}$')
#       5 plt.ylabel('Angle between model and coplanarity normals ${\Theta}_{CPM}$ ')
# ----> 6 plt.errorbar(ave_shock,t,xerr=std,yerr=st,fmt='o',color='k')
#       7 plt.ylim(-10,100)
#       8 plt.xlim(0,90 )
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2602         uplims=False, xlolims=False, xuplims=False, errorevery=1,
#    2603         capthick=None, *, data=None, **kwargs):
# -> 2604     return gca().errorbar(
#    2605         x, y, yerr=yerr, xerr=xerr, fmt=fmt, ecolor=ecolor,
#    2606         elinewidth=elinewidth, capsize=capsize, barsabove=barsabove,
#
# ...
