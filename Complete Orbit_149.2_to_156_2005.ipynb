# %%
from Functions import *

# %%
windowsize = 7
estimatedNumCrossings = 7
year = 2005
start_day = 152
end_day = 154
day_data1 = get_day_data(start_day, end_day, year)
plot_KSM(day_data1, year, start_day, end_day, xFormat = "Hour")
entries1, exits1, ax1, ksmcoords_2_1,cross_array1= identify_crossings_2(day_data1, windowsize, estimatedNumCrossings,3,2,200)
# Out:
# Sample start date:  2005-06-01 00:00:30
# Sample end date: 2005-06-03 00:00:30
# Start Date:  2005-06-01 00:00:30
# End Date:  2005-06-02 23:59:30

# %%
print(len(cross_array1))
# Out:
# 8

# %%
windowsize = 7
estimatedNumCrossings = 12
year = 2005
start_day = 154.2
end_day = 156
day_data2 = get_day_data(start_day, end_day, year)
plot_KSM(day_data2, year, start_day, end_day, xFormat = "Hour")
entries2, exits2, ax2, ksmcoords_2_2,cross_array2= identify_crossings_2(day_data2, windowsize, estimatedNumCrossings,3,2,200)
# Out:
# Sample start date:  2005-06-03 04:48:30
# Sample end date: 2005-06-05 00:00:30
# Start Date:  2005-06-03 04:48:30
# End Date:  2005-06-04 23:59:30

# %%
['2005-06-04 03:02:30', '2005-06-04 03:24:30']
# Out:
# ['2005-06-04 03:02:30', '2005-06-04 03:24:30']

# %%
print(cross_array2)

if '2005-06-04 03:02:30' not in cross_array2:
    cross_array2.insert(3,'2005-06-04 03:02:30')
print(len(cross_array2))
# Out:
# ['2005-06-03 11:04:30', '2005-06-03 20:47:30', '2005-06-03 21:32:30', '2005-06-04 03:24:30', '2005-06-04 06:03:30', '2005-06-04 08:49:30', '2005-06-04 10:44:30', '2005-06-04 18:37:30', '2005-06-04 20:42:30', '2005-06-04 23:44:30']
# 11

# %%
cross_array_total = cross_array1+cross_array2
print(cross_array_total)
print(len(cross_array_total))
# Out:
# ['2005-06-01 16:15:30', '2005-06-01 17:06:30', '2005-06-01 19:41:30', '2005-06-01 21:43:30', '2005-06-02 01:10:30', '2005-06-02 04:58:30', '2005-06-02 18:33:30', '2005-06-02 20:20:30', '2005-06-03 11:04:30', '2005-06-03 20:47:30', '2005-06-03 21:32:30', '2005-06-04 03:02:30', '2005-06-04 03:24:30', '2005-06-04 06:03:30', '2005-06-04 08:49:30', '2005-06-04 10:44:30', '2005-06-04 18:37:30', '2005-06-04 20:42:30', '2005-06-04 23:44:30']
# 19

# %%
day_data = get_day_data(152,156, 2005)
# Out:
# Sample start date:  2005-06-01 00:00:30
# Sample end date: 2005-06-05 00:00:30

# %%
BU1 = selectBvector('2005-06-01 00:00:30', cross_array_total[0], time_width = 40, data = day_data , exclude_time = 5)
BD1 = selectBvector(cross_array_total[0],cross_array_total[1], time_width = 40, data = day_data , exclude_time = 5)

BD2 = selectBvector(cross_array_total[0], cross_array_total[1], time_width = 40, data = day_data , exclude_time = 5)
BU2= selectBvector(cross_array_total[1], cross_array_total[2], time_width = 40, data = day_data , exclude_time = 5)

BU3 = selectBvector(cross_array_total[1], cross_array_total[2], time_width = 40, data = day_data , exclude_time = 5)
BD3 = selectBvector(cross_array_total[2], cross_array_total[3], time_width = 40, data = day_data , exclude_time = 5)

BD4 = selectBvector(cross_array_total[2], cross_array_total[3], time_width = 40, data = day_data , exclude_time = 5)
BU4 = selectBvector(cross_array_total[3], cross_array_total[4], time_width = 40, data = day_data , exclude_time = 5)

BU5 = selectBvector(cross_array_total[3], cross_array_total[4], time_width = 40, data = day_data , exclude_time = 5)
BD5 = selectBvector(cross_array_total[4], cross_array_total[5], time_width = 40, data = day_data , exclude_time = 5)

BD6 = selectBvector(cross_array_total[4], cross_array_total[5], time_width = 40, data = day_data , exclude_time = 5)
BU6 = selectBvector(cross_array_total[5], cross_array_total[6], time_width = 40, data = day_data , exclude_time = 5)

BU7 = selectBvector(cross_array_total[5], cross_array_total[6], time_width = 40, data = day_data , exclude_time = 5)
BD7 = selectBvector(cross_array_total[6], cross_array_total[7], time_width = 40, data = day_data , exclude_time = 5)

BD8 = selectBvector(cross_array_total[6], cross_array_total[7], time_width = 40, data = day_data , exclude_time = 5)
BU8 = selectBvector(cross_array_total[7], cross_array_total[8], time_width = 40, data = day_data , exclude_time = 5)

BU9 = selectBvector(cross_array_total[7], cross_array_total[8], time_width = 40, data = day_data , exclude_time = 5)
BD9 = selectBvector(cross_array_total[8], cross_array_total[9], time_width = 40, data = day_data , exclude_time = 5)

BD10 = selectBvector(cross_array_total[8], cross_array_total[9], time_width = 40, data = day_data , exclude_time = 5)
BU10 = selectBvector(cross_array_total[9], cross_array_total[10], time_width = 20, data = day_data , exclude_time = 2)

BU11 = selectBvector(cross_array_total[9], cross_array_total[10], time_width = 20, data = day_data , exclude_time = 2)
BD11 = selectBvector(cross_array_total[10], cross_array_total[11], time_width = 20, data = day_data , exclude_time = 2)

BD12 = selectBvector(cross_array_total[10], cross_array_total[11], time_width = 20, data = day_data , exclude_time = 5)
BU12 = selectBvector(cross_array_total[11], cross_array_total[12], time_width = 20, data = day_data , exclude_time = 1)

BU13 = selectBvector(cross_array_total[11], cross_array_total[12], time_width = 20, data = day_data , exclude_time = 1)
BD13 = selectBvector(cross_array_total[12], cross_array_total[13], time_width = 20, data = day_data , exclude_time = 1)

BD14 = selectBvector(cross_array_total[12], cross_array_total[13], time_width = 20, data = day_data , exclude_time = 1)
BU14 = selectBvector(cross_array_total[13], cross_array_total[14], time_width = 20, data = day_data , exclude_time = 1)

BU15 = selectBvector(cross_array_total[13], cross_array_total[14], time_width = 20, data = day_data , exclude_time = 1)
BD15 = selectBvector(cross_array_total[14], cross_array_total[15], time_width = 20, data = day_data , exclude_time = 1)

BD16 = selectBvector(cross_array_total[14], cross_array_total[15], time_width = 20, data = day_data , exclude_time = 1)
BU16 = selectBvector(cross_array_total[15], cross_array_total[16], time_width = 20, data = day_data , exclude_time = 1)

BU17 = selectBvector(cross_array_total[15], cross_array_total[16], time_width = 20, data = day_data , exclude_time = 1)
BD17 = selectBvector(cross_array_total[16], cross_array_total[17], time_width = 20, data = day_data , exclude_time = 1)

BD18 = selectBvector(cross_array_total[16], cross_array_total[17], time_width = 20, data = day_data , exclude_time = 1)
BU18 = selectBvector(cross_array_total[17], cross_array_total[18], time_width = 20, data = day_data , exclude_time = 1)

# %%
ncps = {}
shock_vs = {}
aves = {}
stds = {}
BU_list = [BU1,BU2,BU3,BU4,BU5,BU6,BU7,BU8, BU9,BU10,BU11,BU12,BU13,BU14,BU15,BU16,BU17,BU18]
BD_list = [BD1,BD2,BD3,BD4,BD5,BD6,BD7,BD8, BD9,BD10,BD11,BD12,BD13,BD14,BD15,BD16,BD17,BD18]
for i in range(len(BU_list)):
    ncp,shock_value,ave,std = ncp_shock4(BU_list[i],BD_list[i],5,i+1)
    ncps['ncp'+str(i+1)] = ncp
    shock_vs['shock_value'+str(i+1)] = shock_value
    aves['average_shock'+str(i+1)] = ave
    stds['std'+str(i+1)] = std
# Out:
# S=1 θ_BN value = 46.752897259149165
# Standard deviation = 3.9894127358776403
# S=2 θ_BN value = 57.23625173865564
# Standard deviation = 4.409824366760064
# S=3 θ_BN value = 74.95399915772819
# Standard deviation = 4.3960564984270265
# S=4 θ_BN value = 64.09245815888794
# Standard deviation = 2.282733912026034
# S=5 θ_BN value = 86.98814950928097
# Standard deviation = 1.7883615614552408
# S=6 θ_BN value = 63.78437856498536
# Standard deviation = 2.60121269910846
# S=7 θ_BN value = 73.08927310244786
# Standard deviation = 3.2124930255192106
# S=8 θ_BN value = 47.52763618398779
# Standard deviation = 3.7103472581909593
# S=9 θ_BN value = 83.88995731251197
# Standard deviation = 3.9566885635845632
# S=10 θ_BN value = 56.9987180380864
# Standard deviation = 3.698946594000652
# S=11 θ_BN value = 83.03384745551206
# Standard deviation = 1.3546893794504704
# S=12 θ_BN value = 75.697120044737
# Standard deviation = 2.5878635183167487
# S=13 θ_BN value = 63.66131467832025
# Standard deviation = 3.50587967917785
# S=14 θ_BN value = 16.752326051602253
# Standard deviation = 6.015211560146526
# S=15 θ_BN value = 62.92823734774772
# Standard deviation = 8.38791418976352
# S=16 θ_BN value = 35.556174784422375
# Standard deviation = 1.9268654748892995
# S=17 θ_BN value = 39.66532871658369
# Standard deviation = 11.922480671849621
# S=18 θ_BN value = 51.96773434716329
# Standard deviation = 21.001895733355862

# %%
shock_vs_list = []
for i in shock_vs.values():
    shock_vs_list.append(i)
Plot_Dist_for_theta(shock_vs_list)
plt.title("Kurtosis vs Skewness for Days 149.2 to 156, 2005", fontsize = 15)
plt.xlabel("Kurtosis of ${\Theta}_{BN}$", fontsize = 15)
plt.ylabel("Skewness of ${\Theta}_{BN}$", fontsize = 15)
# Out:
# Text(0, 0.5, 'Skewness of ${\\Theta}_{BN}$')

# %%
ncp_list = []
ave_ncp = []
std_ncp = []
for value in ncps.values():
    ncp_list.append(value)
print(len(ncp_list[0]))
for i in range(18):
    ncp_S = ncp_list[i]
    ave_value = np.sum(ncp_S, axis =0)/len(ncp_S)
    ave_ncp.append(ave_value)
    std = np.sqrt(np.sum((ncp_S - ave_value)**2, axis = 0)/len(ncp_S))
    std_ncp.append(std)
print(ave_value)
# Out:
# 25
# [-0.6335914  -0.6335914   0.31682818]

# %%
print(len(ave_ncp))
for i in ave_ncp:
    print(i)
# Out:
# 18
# [-0.85527072 -0.22630431 -0.45944252]
# [-0.08958003  0.42260168  0.89650607]
# [-0.22023427  0.6855594   0.64843395]
# [-0.97136686  0.01948474 -0.20192782]
# [0.31223456 0.31223456 0.71451748]
# [ 0.00655119 -0.76792084 -0.62848041]
# [ 0.59827578 -0.58324922  0.52043715]
# [-0.2310563  -0.2310563  -0.94477845]
# [ 0.13269615  0.13269615 -0.65354172]
# [-0.33941938 -0.33941938  0.87492333]
# [-0.13750949 -0.13750949 -0.98067128]
# [ 0.56609152 -0.50581502  0.62946955]
# [ 0.19247072 -0.39417497  0.89655604]
# [-0.10667808 -0.10667808 -0.98835827]
# [-0.57726598 -0.57726598 -0.5747181 ]
# [-0.49146802 -0.49146802 -0.7184843 ]
# [-0.60393969 -0.60393969  0.47783344]
# [-0.6335914  -0.6335914   0.31682818]

# %%
print(len(cross_array_total))
print(len(ave_ncp))
cross_array_total.pop()
# Out:
# 19
# 18
# '2005-06-04 23:44:30'

# %%
plt.figure(figsize = (10,12))
x_ncp,rho_ncp,srho_ncp=plotncp(day_data,cross_array_total,-1,ave_ncp,std_ncp,0,1)
plt.ylim(0,40)
plt.xlim(18,24)
plt.gca().invert_yaxis()

# %%
t,st=calCPM(day_data,cross_array_total,ave_ncp,rho_ncp,std_ncp,srho_ncp)

plt.ylim(30,36)
plt.xlim(19,22)
# Out:
# Theta_CPM  [47.39818877038004, 49.18222651957831, 43.00680120321644, 29.780555842739155, 79.28440280317636, 60.0500635374232, 13.90658733830756, 80.6840611895659, 58.92052192689448, 64.61107468068596, 82.80402082441178, 13.708504560532987, 34.26902443108549, 84.55097691011913, 71.62676015582095, 72.25942159089334, 66.59368391792788, 67.03171066434822]
# Std [4.317294788749031, 4.71127981561927, 12.107580305808778, 7.150369961485889, 5.349958024682324, 6.741986450485847, 3.650518980384098, 0.5836585185137069, 11.011439147935869, 1.20160161818667, 0.6710565508040351, 4.55913468761118, 2.6570028632544522, 0.6757293389887001, 0.3909702157776282, 0.24961553329185993, 1.515882327141861, 1.7383167161654283]
# (19.0, 22.0)
